# %% [markdown]
# <a href="https://colab.research.google.com/github/aleszcz/Aleks_portfolio/blob/main/Python_for_Cathepsin_D_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(
[[1,25,2],
[1,5,4],
[1,10,3],
[1,35,1],
[1,20,1],
[2,40,5],
[2,20,3],
[2,5,1],
[2,50,5],
[2,10,2],
[2,15,1],
[2,70,1],
[2,30,1],
[2,75,1],
[2,25,1],
[3,50,5],
[3,20,4],
[3,25,4],
[3,75,2],
[3,10,3],
[3,60,1],
[3,5,1],
[3,40,1]],
columns=['cathepsin', 'small droplet', 'sample_size'])
df
# Out:
#     cathepsin  small droplet  sample_size
# 0           1             25            2
# 1           1              5            4
# 2           1             10            3
# 3           1             35            1
# 4           1             20            1
# 5           2             40            5
# 6           2             20            3
# 7           2              5            1
# 8           2             50            5
# 9           2             10            2
# 10          2             15            1
# 11          2             70            1
# 12          2             30            1
# 13          2             75            1
# 14          2             25            1
# 15          3             50            5
# 16          3             20            4
# 17          3             25            4
# 18          3             75            2
# 19          3             10            3
# 20          3             60            1
# ...

# %%
fig, ax = plt.subplots(figsize=(4,3), dpi=100)
for i, (x, y, s) in df.iterrows():
    ax.scatter([x], [y], s=s*100, c="blue", alpha=0.5)
ax.set_xlabel(df.columns[0])
ax.set_ylabel(df.columns[1])
plt.show()
